# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Funcion de Analisis Exploratorio de Datos

# %%
# Funcion para un Análisis Exploratorio inicial de los datos
def exploracion_inicial(df, tipo=None):
    print("¿Cuántas filas y columnas hay en el conjunto de datos?")
    num_filas, num_columnas = df.shape
    print(f"\tHay {num_filas:,} filas y {num_columnas:,} columnas.")
    print('#' * 90)

    if tipo == 'simple':
        print("¿Cuáles son las primeras dos filas del conjunto de datos?")
        display(df.head(2))
    else:
        print("¿Cuáles son las primeras cinco filas del conjunto de datos?")
        display(df.head())

        print("¿Cuáles son las últimas cinco filas del conjunto de datos?")
        display(df.tail())

        print("¿Cómo puedes obtener una muestra aleatoria de filas del conjunto de datos?")
        display(df.sample(n=5))

        print("¿Cuáles son las columnas del conjunto de datos?")
        print("\n".join(f"\t- {col}" for col in df.columns))

        print("¿Cuál es el tipo de datos de cada columna?")
        print(df.dtypes)

        print("¿Cuántas columnas hay de cada tipo de datos?")
        print(df.dtypes.value_counts())

        print("¿Cómo podríamos obtener información más completa sobre la estructura y el contenido del DataFrame?")
        df.info()

        print("¿Cuántos valores únicos tiene cada columna?")
        print(df.nunique())

        print("¿Cuáles son las estadísticas descriptivas básicas de todas las columnas?")
        display(df.describe(include='all').fillna(''))

        print("¿Hay valores nulos en el conjunto de datos?")
        print(df.isnull().sum())

        print("¿Cuál es la proporción de valores nulos en cada columna?")
        print((df.isnull().sum() / len(df) * 100).round(2))

    print('#' * 90)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Carga de Datos

# %%
df_sellers = pd.read_csv('/content/olist_sellers_dataset.csv')

# %% [markdown]
# ### Exploracion Inicial de Datos (EDA)

# %%
exploracion_inicial(df_sellers)
# Out:
# ¿Cuántas filas y columnas hay en el conjunto de datos?
# 	Hay 3,095 filas y 4 columnas.
# ##########################################################################################
# ¿Cuáles son las primeras cinco filas del conjunto de datos?
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# ¿Cuáles son las últimas cinco filas del conjunto de datos?
#                              seller_id  seller_zip_code_prefix seller_city  \
# ...

# %% [markdown]
# #### Comprobacion de Duplicados

# %%
df_sellers.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No existen duplicados en este dataset

# %% [markdown]
# #### Comprobacion de Nulos

# %%
df_sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# No existen Nulos en este Dataset

# %% [markdown]
# #### Comprobación de que no existen datos extraños en la variable de ciudad

# %%
df_sellers["seller_city"].unique()
# Out:
# array(['campinas', 'mogi guacu', 'rio de janeiro', 'sao paulo',
#        'braganca paulista', 'brejao', 'penapolis', 'curitiba', 'anapolis',
#        'itirapina', 'tubarao', 'lauro de freitas', 'imbituba', 'brasilia',
#        'porto seguro', 'guaruja', 'tabatinga', 'salto', 'tres de maio',
#        'belo horizonte', 'arapongas', 'sao bernardo do campo', 'tatui',
#        'garopaba', 'camanducaia', 'tupa', 'guarulhos',
#        'sao jose dos pinhais', 'sao ludgero', 'sao jose', 'piracicaba',
#        'porto alegre', 'congonhal', 'santo andre', 'osasco', 'valinhos',
#        'joinville', 'saquarema', 'barra velha', 'petropolis',
#        'santo antonio da patrulha', 'ponta grossa', 'santana de parnaiba',
#        'sao carlos', 'ibitinga', 'barueri', 'caxias do sul', 'araguari',
#        'contagem', 'jaragua do sul', 'lages - sc', 'bento goncalves',
#        'catanduva', 'ribeirao pires', 'jaboticabal', 'echapora', 'cotia',
# ...

# %% [markdown]
# Existen ciudades escritas de forma errónea y datos que no corresponden a ciudades

# %%
# Sao Paulo
df_sellers.loc[df_sellers["seller_city"] == "sao pauo", "seller_city"] = "sao paulo"
df_sellers.loc[df_sellers["seller_city"] == "sao paluo", "seller_city"] = "sao paulo"
df_sellers.loc[df_sellers["seller_city"] == "sp / sp", "seller_city"] = "sao paulo"
df_sellers.loc[df_sellers["seller_city"] == "sao paulo sp", "seller_city"] = "sao paulo"
df_sellers.loc[df_sellers["seller_city"] == "sao paulo / sao paulo", "seller_city"] = "sao paulo"
df_sellers.loc[df_sellers["seller_city"] == "são paulo", "seller_city"] = "sao paulo"
df_sellers.loc[df_sellers["seller_city"] == "sao paulop", "seller_city"] = "sao paulo"
df_sellers.loc[df_sellers["seller_city"] == "sao paluo", "seller_city"] = "sao paulo"

# Rio de Janeiro
df_sellers.loc[df_sellers["seller_city"] == "rio de janeiro / rj", "seller_city"] = "rio de janeiro"
df_sellers.loc[df_sellers["seller_city"] == "rio de janeiro / rio de janeiro", "seller_city"] = "rio de janeiro"
df_sellers.loc[df_sellers["seller_city"] == "rio de janeiro \rio de janeiro", "seller_city"] = "rio de janeiro"

# Sao Jose Do Rio Preto
df_sellers.loc[df_sellers["seller_city"] == "sao jose do rio preto", "seller_city"] = "sao jose do rio preto"
df_sellers.loc[df_sellers["seller_city"] == "sao jose do rio pret", "seller_city"] = "sao jose do rio preto"
df_sellers.loc[df_sellers["seller_city"] == "s jose do rio preto", "seller_city"] = "sao jose do rio preto"
df_sellers.loc[df_sellers["seller_city"] == "sao jose do rio pret", "seller_city"] = "sao jose do rio preto"
df_sellers.loc[df_sellers["seller_city"] == "s jose do rio preto", "seller_city"] = "sao jose do rio preto"

# Angra dos Reis
df_sellers.loc[df_sellers["seller_city"] == "angra dos reis rj", "seller_city"] = "angra dos reis"

# Ribeirao Preto
df_sellers.loc[df_sellers["seller_city"] == "ribeirao preto / sao paulo", "seller_city"] = "ribeirao preto"
df_sellers.loc[df_sellers["seller_city"] == "robeirao preto", "seller_city"] = "ribeirao preto"


# Sao Bernardo do Campo
df_sellers.loc[df_sellers["seller_city"] == "sbc", "seller_city"] = "sao bernardo do campo"
df_sellers.loc[df_sellers["seller_city"] == "sbc/sp", "seller_city"] = "sao bernardo do campo"

# Sao Jose Do Rio Pardo
df_sellers.loc[df_sellers["seller_city"] == "scao jose do rio pardo", "seller_city"] = "sao jose do rio pardo"

# Sao Sebastiao Da Grama
df_sellers.loc[df_sellers["seller_city"] == "sao sebastiao da grama/sp", "seller_city"] = "sao sebastiao da grama"

# Carapicuiba
df_sellers.loc[df_sellers["seller_city"] == "carapicuiba / sao paulo", "seller_city"] = "carapicuiba"

# Jacarei
df_sellers.loc[df_sellers["seller_city"] == "jacarei / sao paulo", "seller_city"] = "jacarei"

# Santa Barbara D'oeste
df_sellers.loc[df_sellers["seller_city"] == "santa barbara d oeste", "seller_city"] = "santa barbara do oeste"

# Novo Hamburgo
df_sellers.loc[df_sellers["seller_city"] == "novo hamburgo, rio grande do sul, brasil", "seller_city"] = "novo hamburgo"

# Cariacica
df_sellers.loc[df_sellers["seller_city"] == "cariacica / es", "seller_city"] = "cariacica"

# Lages
df_sellers.loc[df_sellers["seller_city"] == "lages - sc", "seller_city"] = "lages"

# Auriflama
df_sellers.loc[df_sellers["seller_city"] == "auriflama/sp", "seller_city"] = "auriflama"

# Mogi das Cruzes
df_sellers.loc[df_sellers["seller_city"] == "mogi das cruzes / sp", "seller_city"] = "mogi das cruzes"

# Andira
df_sellers.loc[df_sellers["seller_city"] == "andira-pr", "seller_city"] = "andira"

# Barbacena
df_sellers.loc[df_sellers["seller_city"] == "barbacena/ minas gerais", "seller_city"] = "barbacena"

# Arrial d´Ajuda
df_sellers.loc[df_sellers["seller_city"] == "arraial d'ajuda (porto seguro)", "seller_city"] = "arrial d'ajuda"

# Brasilia
df_sellers.loc[df_sellers["seller_city"] == "brasilia df", "seller_city"] = "brasilia"

# Maua
df_sellers.loc[df_sellers["seller_city"] == "maua/sao paulo", "seller_city"] = "maua"

# Santo Andre
df_sellers.loc[df_sellers["seller_city"] == "santo andre/sao paulo", "seller_city"] = "santo andre"

# %% [markdown]
# Eliminamos la información errónea / extraña

# %%
df_sellers.loc[df_sellers["seller_city"] == "vendas@creditparts.com.br", "seller_city"] = "sin informacion"
df_sellers.loc[df_sellers["seller_city"] == "04482255", "seller_city"] = "sin informacion"

# %%
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Representaciones Gráficas

# %% [markdown]
# ### Estados con mas ventas

# %%
# Graficamos el countplot
plt.figure(figsize=(15,7))
p = sns.countplot(x='seller_state', data=df_sellers, palette="Spectral")

p.set(xlabel="Estado", ylabel="Número de Vendedores")
plt.title('Cantidad de Vendedores por estado', fontsize=16)

# Total de vendedores (para calcular porcentaje)
n = len(df_sellers)

# Añadir número + porcentaje a cada barra
for k in p.patches:
    height = k.get_height()
    percentage = height / n
    p.text(
        k.get_x() + k.get_width()/2.,
        height,
        f'{height}\n({percentage:.1%})',
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-6-1709048057>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   p = sns.countplot(x='seller_state', data=df_sellers, palette="Spectral")

# %% [markdown]
# ### to CSV

# %%
df_sellers.to_csv('sellers_clean.csv', index=False)
