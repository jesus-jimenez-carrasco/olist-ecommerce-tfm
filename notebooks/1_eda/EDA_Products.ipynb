# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Funcion Analisis Exploratorio de Datos

# %%
# Funcion para un Análisis Exploratorio inicial de los datos
def exploracion_inicial(df, tipo=None):
    print("¿Cuántas filas y columnas hay en el conjunto de datos?")
    num_filas, num_columnas = df.shape
    print(f"\tHay {num_filas:,} filas y {num_columnas:,} columnas.")
    print('#' * 90)

    if tipo == 'simple':
        print("¿Cuáles son las primeras dos filas del conjunto de datos?")
        display(df.head(2))
    else:
        print("¿Cuáles son las primeras cinco filas del conjunto de datos?")
        display(df.head())

        print("¿Cuáles son las últimas cinco filas del conjunto de datos?")
        display(df.tail())

        print("¿Cómo puedes obtener una muestra aleatoria de filas del conjunto de datos?")
        display(df.sample(n=5))

        print("¿Cuáles son las columnas del conjunto de datos?")
        print("\n".join(f"\t- {col}" for col in df.columns))

        print("¿Cuál es el tipo de datos de cada columna?")
        print(df.dtypes)

        print("¿Cuántas columnas hay de cada tipo de datos?")
        print(df.dtypes.value_counts())

        print("¿Cómo podríamos obtener información más completa sobre la estructura y el contenido del DataFrame?")
        df.info()

        print("¿Cuántos valores únicos tiene cada columna?")
        print(df.nunique())

        print("¿Cuáles son las estadísticas descriptivas básicas de todas las columnas?")
        display(df.describe(include='all').fillna(''))

        print("¿Hay valores nulos en el conjunto de datos?")
        print(df.isnull().sum())

        print("¿Cuál es la proporción de valores nulos en cada columna?")
        print((df.isnull().sum() / len(df) * 100).round(2))

    print('#' * 90)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Carga de Datos

# %%
df_products = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets TFM/olist_products_dataset.csv")

# %% [markdown]
# ### Exploración Inicial de los Datos

# %%
exploracion_inicial(df_products)
# Out:
# ¿Cuántas filas y columnas hay en el conjunto de datos?
# 	Hay 32,951 filas y 9 columnas.
# ##########################################################################################
# ¿Cuáles son las primeras cinco filas del conjunto de datos?
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# ...

# %% [markdown]
# ### Conclusiones exploración inicial
#
# Este dataset servirá para agregar las descripciones en portugués a los productos incluidos en el df_items
#
# Contiene información detallada de cada producto que aparece en el marketplace.
#
# | Columna           |     Descripción  | Observaciones
# |-------------------|------------------|----------
# | product_id	| Identificador único del producto
# | product_category_name	 | Categoría del producto (en portugués) | con valores nulos -  Reemplazar por "Sin_Informacion"
# | product_name_length	| Longitud del nombre del producto | con valores nulos - Reemplazar por cero
# | product_description_length | Longitud de la descripción | con valores nulos - Reemplazar por cero
# | product_photos_qty | Cantidad de imágenes del producto | con valores nulos - Reemplazar por cero
# | product_weight_g	| Peso del producto en gramos | con valores nulos - Reemplazar por cero
# | product_length_cm	| Largo del producto | con valores nulos - Reemplazar por cero
# | product_height_cm	|Altura del producto | con valores nulos - Reemplazar por cero
# | product_width_cm	|Ancho del producto | con valores nulos - Reemplazar por cero
#
#
# * Se identifica la columna **product_id** con valores únicos (primary key)
#
# * Existen valores nulos en las columnas.  Estos no tienen consecuencias para los análisis estadísticos y su proporción es menor (1.85%).
# Para poder identificarlos y aislarlos si es necesario esos valores nulos se reemplazan por los valores de la tabla

# %% [markdown]
# ### Comprobacion de Duplicados

# %%
df_products.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No existen duplicados en este Dataset

# %% [markdown]
# ### Comprobación de Nulos

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Imputamos "Sin Informacion" los nulos de product_category_name y "0" para el resto de las variables numéricas

# %%
df_products["product_category_name"].fillna("sin información", inplace=True)
df_products["product_description_lenght"].fillna(0, inplace=True)
df_products["product_weight_g"].fillna(0, inplace=True)
df_products["product_length_cm"].fillna(0, inplace=True)
df_products["product_height_cm"].fillna(0, inplace=True)
df_products["product_width_cm"].fillna(0, inplace=True)
df_products["product_name_lenght"].fillna(0, inplace=True)
# Out:
# <ipython-input-9-8f180c8433d1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_products["product_category_name"].fillna("sin información", inplace=True)
# <ipython-input-9-8f180c8433d1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df_products.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ### Representaciones Gráficas

# %% [markdown]
# ### Representación Gráfica de las categorias de productos

# %%
# Calculamos el Top 10 categorías
top_10_categories = df_products['product_category_name'].value_counts().nlargest(10).index

# Filtramos
df_top_10 = df_products[df_products['product_category_name'].isin(top_10_categories)]

# Graficamos
plt.figure(figsize=(15,7))
p = sns.countplot(x="product_category_name", data=df_top_10, palette="Spectral", order=top_10_categories)
p.set(xlabel="Categoría", ylabel="Cantidad")
plt.title('Top 10 Categorías con más productos', fontsize=16)

# Total para calcular porcentajes
n = len(df_products)

# Añadimos cantidad y porcentaje a cada barra
for k in p.patches:
    height = k.get_height()
    percentage = height / n
    p.text(
        k.get_x() + k.get_width()/2.,
        height,
        f'{height}\n({percentage:.1%})',
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-10-cebde81fa9f7>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   p = sns.countplot(x="product_category_name", data=df_top_10, palette="Spectral", order=top_10_categories)

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_products["product_photos_qty"].value_counts()
# Out:
# product_photos_qty
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: count, dtype: int64

# %% [markdown]
# ### Merge

# %%
df_products_translation = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets TFM/product_category_name_translation.csv")

# %%
df_products_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_products = pd.merge(df_products, df_products_translation, on="product_category_name", how="left")

# %%
exploracion_inicial(df_products)
# Out:
# ¿Cuántas filas y columnas hay en el conjunto de datos?
# 	Hay 32,951 filas y 10 columnas.
# ##########################################################################################
# ¿Cuáles son las primeras cinco filas del conjunto de datos?
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# ...

# %%
df_products.fillna("sin informacion")
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# ### to CSV

# %%
df_products.to_csv('products_clean.csv', index=False)
